# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import seaborn as sns
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
from scipy.signal import savgol_filter 
from mpl_toolkits.mplot3d import Axes3D

# %%
path = "C:/Users/StuartM/Downloads/MscProject-main/MscProject-main/MSC Project\ForceD unity demo/Data ID4/"

files = os.listdir(path)

print(files)
# Out:
# ['ID_4_Phase_Baseline_Trial_00.json', 'ID_4_Phase_Baseline_Trial_01.json', 'ID_4_Phase_Baseline_Trial_010.json', 'ID_4_Phase_Baseline_Trial_011.json', 'ID_4_Phase_Baseline_Trial_012.json', 'ID_4_Phase_Baseline_Trial_013.json', 'ID_4_Phase_Baseline_Trial_014.json', 'ID_4_Phase_Baseline_Trial_015.json', 'ID_4_Phase_Baseline_Trial_016.json', 'ID_4_Phase_Baseline_Trial_017.json', 'ID_4_Phase_Baseline_Trial_018.json', 'ID_4_Phase_Baseline_Trial_019.json', 'ID_4_Phase_Baseline_Trial_02.json', 'ID_4_Phase_Baseline_Trial_03.json', 'ID_4_Phase_Baseline_Trial_04.json', 'ID_4_Phase_Baseline_Trial_05.json', 'ID_4_Phase_Baseline_Trial_06.json', 'ID_4_Phase_Baseline_Trial_07.json', 'ID_4_Phase_Baseline_Trial_08.json', 'ID_4_Phase_Baseline_Trial_09.json', 'ID_4_Phase_Test_Trial_00.json', 'ID_4_Phase_Test_Trial_01.json', 'ID_4_Phase_Test_Trial_010.json', 'ID_4_Phase_Test_Trial_011.json', 'ID_4_Phase_Test_Trial_012.json', 'ID_4_Phase_Test_Trial_013.json', 'ID_4_Phase_Test_Trial_014.json', 'ID_4_Phase_Test_Trial_015.json', 'ID_4_Phase_Test_Trial_016.json', 'ID_4_Phase_Test_Trial_017.json', 'ID_4_Phase_Test_Trial_018.json', 'ID_4_Phase_Test_Trial_019.json', 'ID_4_Phase_Test_Trial_02.json', 'ID_4_Phase_Test_Trial_03.json', 'ID_4_Phase_Test_Trial_04.json', 'ID_4_Phase_Test_Trial_05.json', 'ID_4_Phase_Test_Trial_06.json', 'ID_4_Phase_Test_Trial_07.json', 'ID_4_Phase_Test_Trial_08.json', 'ID_4_Phase_Test_Trial_09.json', 'ID_4__Phase_Training_Repelling_Forces_Trial_00.json', 'ID_4__Phase_Training_Repelling_Forces_Trial_01.json', 'ID_4__Phase_Training_Repelling_Forces_Trial_010.json', 'ID_4__Phase_Training_Repelling_Forces_Trial_011.json', 'ID_4__Phase_Training_Repelling_Forces_Trial_012.json', 'ID_4__Phase_Training_Repelling_Forces_Trial_013.json', 'ID_4__Phase_Training_Repelling_Forces_Trial_014.json', 'ID_4__Phase_Training_Repelling_Forces_Trial_015.json', 'ID_4__Phase_Training_Repelling_Forces_Trial_016.json', 'ID_4__Phase_Training_Repelling_Forces_Trial_017.json', 'ID_4__Phase_Training_Repelling_Forces_Trial_018.json', 'ID_4__Phase_Training_Repelling_Forces_Trial_019.json', 'ID_4__Phase_Training_Repelling_Forces_Trial_02.json', 'ID_4__Phase_Training_Repelling_Forces_Trial_03.json', 'ID_4__Phase_Training_Repelling_Forces_Trial_04.json', 'ID_4__Phase_Training_Repelling_Forces_Trial_05.json', 'ID_4__Phase_Training_Repelling_Forces_Trial_06.json', 'ID_4__Phase_Training_Repelling_Forces_Trial_07.json', 'ID_4__Phase_Training_Repelling_Forces_Trial_08.json', 'ID_4__Phase_Training_Repelling_Forces_Trial_09.json']

# %%
tmpDF = None
df = None

i = 0 

for file in files:    
    tmpDF = pd.read_json(path + file)

#     tmpDF.insert(1,'trial', file[-1-6:-1-4])
#     tmpDF.insert(2,'phsae', file[-1-6:-1-4])
    
    if df is None:
        df = tmpDF
    else:
        df = pd.concat((df, tmpDF))

    i = i+1    

df
# Out:
#       frameNum  userID  trialNumber     phase force_type  positional_error  \
# 0            0  User_4            0  Baseline                     2.765631
# 1            1  User_4            0  Baseline                     2.050175
# 2            2  User_4            0  Baseline                     2.050175
# 3            3  User_4            0  Baseline                     2.042871
# 4            4  User_4            0  Baseline                     2.033304
# ...        ...     ...          ...       ...        ...               ...
# 1346      1346  User_4            9  Training  Repelling          0.316468
# 1347      1347  User_4            9  Training  Repelling          0.316083
# 1348      1348  User_4            9  Training  Repelling          0.315317
# 1349      1349  User_4            9  Training  Repelling          0.313784
# 1350      1350  User_4            9  Training  Repelling          0.312863
#
#       x_target_pos  y_target_pos  z_target_pos  x_user_pos  y_user_pos  \
# 0        -5.000000      6.000000      2.000000   -3.278502    5.209771
# 1        -1.601272      4.607640      0.998184   -3.278975    5.209393
# 2        -1.601272      4.607640      0.998184   -3.278975    5.209393
# 3        -1.602868      4.617234      0.995902   -3.277251    5.207085
# 4        -1.604460      4.626798      0.993628   -3.273437    5.202572
# ...            ...           ...           ...         ...         ...
# 1346     -1.296158      5.796858      1.862631   -1.417027    5.795485
# 1347     -1.297512      5.807126      1.860698   -1.411421    5.812363
# 1348     -1.298888      5.817523      1.858732   -1.406124    5.829483
# 1349     -1.300212      5.827488      1.856841   -1.401958    5.844441
# 1350     -1.301573      5.837694      1.854896   -1.398022    5.859969
#
#       z_user_pos  x_pos_error  y_pos_error  z_pos_error        time
# 0      -0.015117    -1.721498     0.790229     2.015117  186.377777
# 1      -0.014942     1.677703    -0.601753     1.013126  186.388900
# 2      -0.014942     1.677703    -0.601753     1.013126  186.400009
# 3      -0.014958     1.674383    -0.589850     1.010861  186.411118
# 4      -0.014997     1.668976    -0.575774     1.008625  186.422226
# ...          ...          ...          ...          ...         ...
# 1346    1.570158     0.120869     0.001373     0.292474  734.977800
# 1347    1.565900     0.113909    -0.005237     0.294798  734.988900
# 1348    1.562451     0.107237    -0.011960     0.296280  735.000000
# 1349    1.560495     0.101746    -0.016953     0.296346  735.011100
# 1350    1.558105     0.096449    -0.022275     0.296791  735.022200
#
# [81053 rows x 16 columns]

# %%
poln = 135 # 51
order = 2 # 3

sampling_rate = 100
df['user_x_vel'] = np.gradient(savgol_filter(df['x_user_pos'], poln,order), (1/sampling_rate))
df['user_y_vel'] = np.gradient(savgol_filter(df['y_user_pos'], poln,order), (1/sampling_rate))
df['user_z_vel'] = np.gradient(savgol_filter(df['z_user_pos'], poln,order), (1/sampling_rate))

df['user_vel'] = np.sqrt(df['user_x_vel']**2 + df['user_y_vel']**2 + df['user_z_vel']**2)

df['target_x_vel'] = np.gradient(savgol_filter(df['x_target_pos'], poln,order), (1/sampling_rate))
df['target_y_vel'] = np.gradient(savgol_filter(df['y_target_pos'], poln,order), (1/sampling_rate))
df['target_z_vel'] = np.gradient(savgol_filter(df['z_target_pos'], poln,order), (1/sampling_rate))

df['target_vel'] = np.sqrt(df['target_x_vel']**2 + df['target_y_vel']**2 + df['target_z_vel']**2)

df['Vel_Error'] = df['target_vel'] - df['user_vel']

# %%
order = ['Baseline', 'Training', 'Testing']
sns.barplot(data=df, x='phase', y='Vel_Error', order=order)
# Out:
# <AxesSubplot:xlabel='phase', ylabel='Vel_Error'>

# %%
order = ['Baseline', 'Training', 'Testing']
sns.barplot(data=df, x='phase', y='positional_error', order=order)
# Out:
# <AxesSubplot:xlabel='phase', ylabel='positional_error'>

# %%
# Filter the DataFrame for userID = 0, phase = 'training', and trialNumber = 2
df_filtered = df[ (df['phase'] == 'Testing') & (df['trialNumber'] == 18)]

# Create a figure and a 3D subplot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Extract coordinates from the filtered DataFrame
x_target = df_filtered['x_target_pos']
y_target = df_filtered['y_target_pos']
z_target = df_filtered['z_target_pos']

x_user = df_filtered['x_user_pos']
y_user = df_filtered['y_user_pos']
z_user = df_filtered['z_user_pos']

# Plot the 3D lines
ax.plot(x_target, y_target, z_target, label='Target Position')
ax.plot(x_user, y_user, z_user, label='User Position')

# Set labels and title
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
ax.set_title('3D Line Graph Example for userID = 4, phase = training, trialNumber = 2')

# Add legend
ax.legend()

# Show the plot
plt.show()

# %%
sns.lineplot(data=df, x='time', y='x_target_pos', label='Target Velocity')
sns.lineplot(data=df, x='time', y='x_user_pos', label='End Effector')  # Adding the new y variable
plt.xlabel('Time')
plt.ylabel('Value')
plt.title('Comparison of Target Velocity and End Effector')
plt.legend()
plt.ylim([-5,6])
plt.show()

# %%
# Filter the DataFrame for userID = 0, phase = 'training', and trialNumber = 2
df_filtered = df[ (df['phase'] == 'Training') & (df['trialNumber'] == 10)]

# Create a figure and a 3D subplot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Extract coordinates from the filtered DataFrame
x_target = df_filtered['target_x_vel']
y_target = df_filtered['target_y_vel']
z_target = df_filtered['target_z_vel']

x_user = df_filtered['user_x_vel']
y_user = df_filtered['user_y_vel']
z_user = df_filtered['user_z_vel']

# Plot the 3D lines
ax.plot(x_target, y_target, z_target, label='Target Velocity')
ax.plot(x_user, y_user, z_user, label='User Velocity')

# Set labels and title
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
ax.set_title('3D Line Graph Example for userID = 4, phase = training, trialNumber = 2')

# Add legend
ax.legend()

# Show the plot
plt.show()
